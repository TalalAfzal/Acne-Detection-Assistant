# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17560, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 17560 (delta 32), reused 7 (delta 7), pack-reused 17507 (from 3)
# Receiving objects: 100% (17560/17560), 16.63 MiB | 30.53 MiB/s, done.
# Resolving deltas: 100% (12026/12026), done.

# %%
# !unzip Acne\ detection.v2i.yolov5pytorch.zip
# Out:
# Archive:  Acne detection.v2i.yolov5pytorch.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/cystic1-114-_jpg.rf.a05595c4516434f1547df8b077286816.jpg
#  extracting: test/images/cystic1-13-_jpg.rf.577839d03956357222eabcbdbe82f238.jpg
#  extracting: test/images/cystic1-19-_jpeg.rf.a151e73e5bc0ec81a5e595a4a99e76d2.jpg
#  extracting: test/images/cystic1-2-_jpeg.rf.87b0cebab234cc74d52c4d5137dd1507.jpg
#  extracting: test/images/cystic1-32-_jpg.rf.c1ff7d600f22ddc892bce925253398ed.jpg
#  extracting: test/images/cystic1-56-_jpg.rf.6d1f7ad52cd8d98180dea34c39d071c8.jpg
#  extracting: test/images/cystic1-58-_jpg.rf.2236e2f50f2a4a899f9fd2fed50a7cb7.jpg
#  extracting: test/images/cystic1-73-_jpg.rf.564c0483fc4f2af9358a8f13147694d2.jpg
#  extracting: test/images/cystic1-8-_jpg.rf.4b274cda4327a8d74aec6ca002bb08c6.jpg
# ...

# %%
# %cd yolov5
# %pip install -qr requirements.txt
# %cd ..

# Train
# !python yolov5/train.py --img 416 --batch 16 --epochs 100 \
  --data data.yaml \
  --weights yolov5m.pt --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#       38/99      4.05G    0.04536      0.032   0.003308        112        416:  45% 17/38 [00:03<00:04,  4.59it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       38/99      4.05G    0.04516    0.03203    0.00323         99        416:  47% 18/38 [00:03<00:04,  4.76it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       38/99      4.05G     0.0451    0.03189   0.003153         91        416:  50% 19/38 [00:04<00:04,  4.61it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp/weights/best.pt \
  --img 416 --conf 0.50 --source test/images
# Out:
# detect: weights=['yolov5/runs/train/exp/weights/best.pt'], source=test/images, data=yolov5/data/coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-429-g50313d30 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20856975 parameters, 0 gradients, 47.9 GFLOPs
# image 1/32 /content/test/images/cystic1-114-_jpg.rf.a05595c4516434f1547df8b077286816.jpg: 416x416 1 cystic, 15.5ms
# image 2/32 /content/test/images/cystic1-13-_jpg.rf.577839d03956357222eabcbdbe82f238.jpg: 416x416 (no detections), 15.6ms
# ...
